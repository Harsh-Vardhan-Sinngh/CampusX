# %% [markdown]
# <a href="https://colab.research.google.com/github/Harsh-Vardhan-Sinngh/CampusX/blob/main/sesssion_22_date_and_time_in_pandas_and_date_time(harsh).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.groupby('sex')[['total_bill']].mean()
# Out:
#         total_bill
# sex
# Male     20.744076
# Female   18.056897

# %%
df.groupby(['sex','smoker'])[['total_bill']].mean().unstack()
# Out:
#        total_bill
# smoker        Yes         No
# sex
# Male    22.284500  19.791237
# Female  17.977879  18.105185

# %%
df.pivot_table(index='sex',columns='smoker')
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in array_func(values)
#    1489             try:
# -> 1490                 result = self.grouper._cython_operation(
#    1491                     "aggregate",
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in _cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     958         ngroups = self.ngroups
# --> 959         return cy_op.cython_operation(
#     960             values=values,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     644         # if not raise NotImplementedError
# --> 645         self._disallow_invalid_ops(dtype, is_numeric)
#     646
#
# ...

# %%
df.pivot_table(index='sex',columns='smoker',values='total_bill')
# Out:
# smoker        Yes         No
# sex
# Male    22.284500  19.791237
# Female  17.977879  18.105185

# %%
df.pivot_table(index='sex',columns='smoker',values='total_bill',aggfunc='sum')
# Out:
# smoker      Yes       No
# sex
# Male    1337.07  1919.75
# Female   593.27   977.68

# %%
df.pivot_table(index=['sex','smoker'],columns=['day','time'],aggfunc={'size':'mean','tip':'max','total_bill':'sum'},margins=True)
# Out:
#                    size                                                 \
# day                Thur              Fri                 Sat       Sun
# time              Lunch Dinner     Lunch    Dinner    Dinner    Dinner
# sex    smoker
# Male   Yes     2.300000    NaN  1.666667  2.400000  2.629630  2.600000
#        No      2.500000    NaN       NaN  2.000000  2.656250  2.883721
# Female Yes     2.428571    NaN  2.000000  2.000000  2.200000  2.500000
#        No      2.500000    2.0  3.000000  2.000000  2.307692  3.071429
# All            2.459016    2.0  2.000000  2.166667  2.517241  2.842105
#
#                           tip               ...       total_bill         \
# day                 All  Thur          Fri  ...   All       Thur
# time                    Lunch Dinner Lunch  ...            Lunch Dinner
# sex    smoker                               ...
# Male   Yes     2.500000  5.00    NaN  2.20  ...  10.0     191.71   0.00
# ...

# %%
df.pivot_table(index='sex',columns='smoker',values='total_bill',aggfunc='sum',margins=True)
# Out:
# smoker      Yes       No      All
# sex
# Male    1337.07  1919.75  3256.82
# Female   593.27   977.68  1570.95
# All     1930.34  2897.43  4827.77

# %%
df=pd.read_csv('/content/expense_data.csv')
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-5f56287d80aa> in <cell line: 1>()
# ----> 1 df=pd.read_csv('/content/expense_data.csv')
#       2 df
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df['Category'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Category'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df['Date']=pd.to_datetime(df['Date'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.info()

# %%
df['month']=df['Date'].dt.month_name()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.pivot_table(index='month',columns='Category',values='INR',aggfunc='sum',fill_value=0).plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-5daf68b71db6> in <cell line: 1>()
# ----> 1 df.pivot_table(index='month',columns='Category',values='INR',aggfunc='sum',fill_value=0).plot()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    8577         from pandas.core.reshape.pivot import pivot_table
#    8578
# -> 8579         return pivot_table(
#    8580             self,
#    8581             values=values,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      95         return table.__finalize__(data, method="pivot_table")
#      96
# ---> 97     table = __internal_pivot_table(
# ...

# %%
df.pivot_table(index='month',columns=['Income/Expense','Account'],values='INR',aggfunc='sum',fill_value=0).plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-c7151f6ebd17> in <cell line: 1>()
# ----> 1 df.pivot_table(index='month',columns=['Income/Expense','Account'],values='INR',aggfunc='sum',fill_value=0).plot()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    8577         from pandas.core.reshape.pivot import pivot_table
#    8578
# -> 8579         return pivot_table(
#    8580             self,
#    8581             values=values,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      95         return table.__finalize__(data, method="pivot_table")
#      96
# ...

# %%
a=np.array([1,2,3,4])
a*4
# Out:
# array([ 4,  8, 12, 16])

# %%
s=['cat','mat',None,'rat']
[i.startswith('c') for i in s  ]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-bd3f5827d9e9> in <cell line: 2>()
#       1 s=['cat','mat',None,'rat']
# ----> 2 [i.startswith('c') for i in s  ]
#
# <ipython-input-26-bd3f5827d9e9> in <listcomp>(.0)
#       1 s=['cat','mat',None,'rat']
# ----> 2 [i.startswith('c') for i in s  ]
#
# AttributeError: 'NoneType' object has no attribute 'startswith'

# %%
s=pd.Series(['cat','mat',None,'rat'])
s.str.startswith('c')
# Out:
# 0     True
# 1    False
# 2     None
# 3    False
# dtype: object

# %%
df=pd.read_csv('/content/titanic.csv')
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Name'].str.lower()
# Out:
# 0                                braund, mr. owen harris
# 1      cumings, mrs. john bradley (florence briggs th...
# 2                                 heikkinen, miss. laina
# 3           futrelle, mrs. jacques heath (lily may peel)
# 4                               allen, mr. william henry
#                              ...
# 886                                montvila, rev. juozas
# 887                         graham, miss. margaret edith
# 888             johnston, miss. catherine helen "carrie"
# 889                                behr, mr. karl howell
# 890                                  dooley, mr. patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Name'].str.upper()
# Out:
# 0                                BRAUND, MR. OWEN HARRIS
# 1      CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...
# 2                                 HEIKKINEN, MISS. LAINA
# 3           FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)
# 4                               ALLEN, MR. WILLIAM HENRY
#                              ...
# 886                                MONTVILA, REV. JUOZAS
# 887                         GRAHAM, MISS. MARGARET EDITH
# 888             JOHNSTON, MISS. CATHERINE HELEN "CARRIE"
# 889                                BEHR, MR. KARL HOWELL
# 890                                  DOOLEY, MR. PATRICK
# Name: Name, Length: 891, dtype: object

# %%
df['Name'].str.capitalize()
# Out:
# 0                                Braund, mr. owen harris
# 1      Cumings, mrs. john bradley (florence briggs th...
# 2                                 Heikkinen, miss. laina
# 3           Futrelle, mrs. jacques heath (lily may peel)
# 4                               Allen, mr. william henry
#                              ...
# 886                                Montvila, rev. juozas
# 887                         Graham, miss. margaret edith
# 888             Johnston, miss. catherine helen "carrie"
# 889                                Behr, mr. karl howell
# 890                                  Dooley, mr. patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Name'].str.title()
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Name'].str.len().max()
# Out:
# 82

# %%
df['Name'][df['Name'].str.len()==82].values[0]
# Out:
# 'Penasco y Castellana, Mrs. Victor de Satode (Maria Josefa Perez de Soto y Vallejo)'

# %%
"     harsh     ".strip()
# Out:
# 'harsh'

# %%
df['Name'].str.strip()
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Name'].str.split(',').str.get(1)
# Out:
# 0                                  Mr. Owen Harris
# 1       Mrs. John Bradley (Florence Briggs Thayer)
# 2                                      Miss. Laina
# 3               Mrs. Jacques Heath (Lily May Peel)
# 4                                Mr. William Henry
#                           ...
# 886                                    Rev. Juozas
# 887                           Miss. Margaret Edith
# 888                 Miss. Catherine Helen "Carrie"
# 889                                Mr. Karl Howell
# 890                                    Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Name'].str.split(',').str.get(0)
# Out:
# 0         Braund
# 1        Cumings
# 2      Heikkinen
# 3       Futrelle
# 4          Allen
#          ...
# 886     Montvila
# 887       Graham
# 888     Johnston
# 889         Behr
# 890       Dooley
# Name: Name, Length: 891, dtype: object

# %%
df['lastname']=df['Name'].str.split(',').str.get(0)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked   lastname
# 0      0         A/5 21171   7.2500   NaN        S     Braund
# 1      0          PC 17599  71.2833   C85        C    Cumings
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3      0            113803  53.1000  C123        S   Futrelle
# ...

# %%
df[['title','firstname']]=df['Name'].str.split(',').str.get(1).str.strip().str.split(' ',n=1,expand=True)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked   lastname  title  \
# 0      0         A/5 21171   7.2500   NaN        S     Braund    Mr.
# 1      0          PC 17599  71.2833   C85        C    Cumings   Mrs.
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen  Miss.
# ...

# %%
df['title'].value_counts()
# Out:
# title
# Mr.          517
# Miss.        182
# Mrs.         125
# Master.       40
# Dr.            7
# Rev.           6
# Mlle.          2
# Major.         2
# Col.           2
# the            1
# Capt.          1
# Ms.            1
# Sir.           1
# Lady.          1
# Mme.           1
# Don.           1
# Jonkheer.      1
# Name: count, dtype: int64

# %%
df['title']=df['title'].str.replace('Ms.','Miss.')
df['title']=df['title'].str.replace('Mile.','Miss.')

# %%
df['title'].value_counts()
# Out:
# title
# Mr.          517
# Miss.        183
# Mrs.         125
# Master.       40
# Dr.            7
# Rev.           6
# Major.         2
# Mlle.          2
# Col.           2
# Don.           1
# Mme.           1
# Lady.          1
# Sir.           1
# Capt.          1
# the            1
# Jonkheer.      1
# Name: count, dtype: int64

# %%
df[df['firstname'].str.startswith('A')]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 13            14         0       3         Andersson, Mr. Anders Johan
# 22            23         1       3         McGowan, Miss. Anna "Annie"
# 35            36         0       1      Holverson, Mr. Alexander Oskar
# 38            39         0       3  Vander Planke, Miss. Augusta Maria
# 61            62         1       1                 Icard, Miss. Amelie
# ..           ...       ...     ...                                 ...
# 842          843         1       1             Serepeca, Miss. Augusta
# 845          846         0       3                 Abbing, Mr. Anthony
# 866          867         1       2        Duran y More, Miss. Asuncion
# 875          876         1       3    Najib, Miss. Adele Kiamie "Jane"
# 876          877         0       3       Gustafsson, Mr. Alfred Ossian
#
#         Sex   Age  SibSp  Parch         Ticket     Fare Cabin Embarked  \
# ...

# %%
df[df['firstname'].str.endswith('A')]
# Out:
#      PassengerId  Survived  Pclass                   Name     Sex  Age  SibSp  \
# 64            65         0       1  Stewart, Mr. Albert A    male  NaN      0
# 303          304         1       2    Keane, Miss. Nora A  female  NaN      0
#
#      Parch    Ticket     Fare Cabin Embarked lastname  title firstname
# 64       0  PC 17605  27.7208   NaN        C  Stewart    Mr.  Albert A
# 303      0    226593  12.3500  E101        Q    Keane  Miss.    Nora A

# %%
df[df['firstname'].str.contains('john',case=False)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 41            42         0       2
# 45            46         0       3
# 98            99         1       2
# 112          113         0       3
# 117          118         0       2
# 160          161         0       3
# 162          163         0       3
# 165          166         1       3
# 168          169         0       1
# 188          189         0       3
# 212          213         0       3
# 226          227         1       2
# 227          228         0       3
# 324          325         0       3
# 328          329         1       3
# 401          402         0       3
# 418          419         0       2
# 467          468         0       1
# 527          528         0       1
# 548          549         0       3
# 549          550         1       2
# 550          551         1       1
# 563          564         0       3
# 572          573         1       1
# ...

# %%
df[df['lastname'].str.contains('^[aeiouAEIOU].+[aeiouAEIOU]$')]
# Out:
#      PassengerId  Survived  Pclass  \
# 30            31         0       1
# 49            50         0       3
# 207          208         1       3
# 210          211         0       3
# 353          354         0       3
# 493          494         0       1
# 518          519         1       2
# 784          785         0       3
# 840          841         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 30                            Uruchurtu, Don. Manuel E    male  40.0      0
# 49       Arnold-Franchi, Mrs. Josef (Josefine Franchi)  female  18.0      1
# 207                        Albimona, Mr. Nassef Cassem    male  26.0      0
# 210                                     Ali, Mr. Ahmed    male  24.0      0
# 353                          Arnold-Franchi, Mr. Josef    male  25.0      1
# 493                            Artagaveytia, Mr. Ramon    male  71.0      0
# ...

# %%
df['Name'].str[1:4]
# Out:
# 0      rau
# 1      umi
# 2      eik
# 3      utr
# 4      lle
#       ...
# 886    ont
# 887    rah
# 888    ohn
# 889    ehr
# 890    ool
# Name: Name, Length: 891, dtype: object

# %%
pd.Timestamp(2024/7/8)
# Out:
# Timestamp('1970-01-01 00:00:00.000000036')

# %%
pd.Timestamp(2024,1,5,9,35)
# Out:
# Timestamp('2024-01-05 09:35:00')

# %%
x=pd.Timestamp(2024,1,5,9,25)

# %%
x.year
# Out:
# 2024

# %%
x.month
# Out:
# 1

# %%
np.array(['2007-07-13', '2006-01-13', '2010-08-13'], dtype='datetime64')
# Out:
# array(['2007-07-13', '2006-01-13', '2010-08-13'], dtype='datetime64[D]')

# %%
date=np.array('2007-07-13', dtype='datetime64')

# %%
date+np.arange(12)
# Out:
# array(['2007-07-13', '2007-07-14', '2007-07-15', '2007-07-16',
#        '2007-07-17', '2007-07-18', '2007-07-19', '2007-07-20',
#        '2007-07-21', '2007-07-22', '2007-07-23', '2007-07-24'],
#       dtype='datetime64[D]')

# %%
dt_index=pd.DatetimeIndex(['2027-5-1','2024-5-12','2025-5-10'])

# %%
pd.Series([1,2,3],index=dt_index)
# Out:
# 2027-05-01    1
# 2024-05-12    2
# 2025-05-10    3
# dtype: int64

# %%
pd.date_range(start='2024/1/5',end='2024/2/25',freq='3D')
# Out:
# DatetimeIndex(['2024-01-05', '2024-01-08', '2024-01-11', '2024-01-14',
#                '2024-01-17', '2024-01-20', '2024-01-23', '2024-01-26',
#                '2024-01-29', '2024-02-01', '2024-02-04', '2024-02-07',
#                '2024-02-10', '2024-02-13', '2024-02-16', '2024-02-19',
#                '2024-02-22', '2024-02-25'],
#               dtype='datetime64[ns]', freq='3D')

# %%
pd.date_range(start='2024/1/5',end='2024/2/25',freq='B')
# Out:
# DatetimeIndex(['2024-01-05', '2024-01-08', '2024-01-09', '2024-01-10',
#                '2024-01-11', '2024-01-12', '2024-01-15', '2024-01-16',
#                '2024-01-17', '2024-01-18', '2024-01-19', '2024-01-22',
#                '2024-01-23', '2024-01-24', '2024-01-25', '2024-01-26',
#                '2024-01-29', '2024-01-30', '2024-01-31', '2024-02-01',
#                '2024-02-02', '2024-02-05', '2024-02-06', '2024-02-07',
#                '2024-02-08', '2024-02-09', '2024-02-12', '2024-02-13',
#                '2024-02-14', '2024-02-15', '2024-02-16', '2024-02-19',
#                '2024-02-20', '2024-02-21', '2024-02-22', '2024-02-23'],
#               dtype='datetime64[ns]', freq='B')

# %%
pd.date_range(start='2024/1/5',end='2024/2/25',freq='W')
# Out:
# DatetimeIndex(['2024-01-07', '2024-01-14', '2024-01-21', '2024-01-28',
#                '2024-02-04', '2024-02-11', '2024-02-18', '2024-02-25'],
#               dtype='datetime64[ns]', freq='W-SUN')

# %%
pd.date_range(start='2024/1/5',end='2024/2/25',freq='W-THU')
# Out:
# DatetimeIndex(['2024-01-11', '2024-01-18', '2024-01-25', '2024-02-01',
#                '2024-02-08', '2024-02-15', '2024-02-22'],
#               dtype='datetime64[ns]', freq='W-THU')

# %%
pd.date_range(start='2024/1/5',end='2024/2/25',freq='h')
# Out:
# DatetimeIndex(['2024-01-05 00:00:00', '2024-01-05 01:00:00',
#                '2024-01-05 02:00:00', '2024-01-05 03:00:00',
#                '2024-01-05 04:00:00', '2024-01-05 05:00:00',
#                '2024-01-05 06:00:00', '2024-01-05 07:00:00',
#                '2024-01-05 08:00:00', '2024-01-05 09:00:00',
#                ...
#                '2024-02-24 15:00:00', '2024-02-24 16:00:00',
#                '2024-02-24 17:00:00', '2024-02-24 18:00:00',
#                '2024-02-24 19:00:00', '2024-02-24 20:00:00',
#                '2024-02-24 21:00:00', '2024-02-24 22:00:00',
#                '2024-02-24 23:00:00', '2024-02-25 00:00:00'],
#               dtype='datetime64[ns]', length=1225, freq='H')

# %%
pd.date_range(start='2024/1/5',end='2024/2/25',freq='3H')
# Out:
# DatetimeIndex(['2024-01-05 00:00:00', '2024-01-05 03:00:00',
#                '2024-01-05 06:00:00', '2024-01-05 09:00:00',
#                '2024-01-05 12:00:00', '2024-01-05 15:00:00',
#                '2024-01-05 18:00:00', '2024-01-05 21:00:00',
#                '2024-01-06 00:00:00', '2024-01-06 03:00:00',
#                ...
#                '2024-02-23 21:00:00', '2024-02-24 00:00:00',
#                '2024-02-24 03:00:00', '2024-02-24 06:00:00',
#                '2024-02-24 09:00:00', '2024-02-24 12:00:00',
#                '2024-02-24 15:00:00', '2024-02-24 18:00:00',
#                '2024-02-24 21:00:00', '2024-02-25 00:00:00'],
#               dtype='datetime64[ns]', length=409, freq='3H')

# %%
pd.date_range(start='2024/1/5',end='2024/2/25',freq='M')
# Out:
# DatetimeIndex(['2024-01-31'], dtype='datetime64[ns]', freq='M')

# %%
pd.date_range(start='2024/1/5',end='2024/2/25',freq='MS')
# Out:
# DatetimeIndex(['2024-02-01'], dtype='datetime64[ns]', freq='MS')

# %%
pd.date_range(start='2024/1/5',end='2030/2/28',freq='A')
# Out:
# DatetimeIndex(['2024-12-31', '2025-12-31', '2026-12-31', '2027-12-31',
#                '2028-12-31', '2029-12-31'],
#               dtype='datetime64[ns]', freq='A-DEC')

# %%
pd.date_range(start='2024/1/5',periods=25,freq='D')
# Out:
# DatetimeIndex(['2024-01-05', '2024-01-06', '2024-01-07', '2024-01-08',
#                '2024-01-09', '2024-01-10', '2024-01-11', '2024-01-12',
#                '2024-01-13', '2024-01-14', '2024-01-15', '2024-01-16',
#                '2024-01-17', '2024-01-18', '2024-01-19', '2024-01-20',
#                '2024-01-21', '2024-01-22', '2024-01-23', '2024-01-24',
#                '2024-01-25', '2024-01-26', '2024-01-27', '2024-01-28',
#                '2024-01-29'],
#               dtype='datetime64[ns]', freq='D')

# %%
s=pd.Series(['2023/1/1','2202/5/2','2014/8/25'])
s
# Out:
# 0     2023/1/1
# 1     2202/5/2
# 2    2014/8/25
# dtype: object

# %%
s.str.split('/').str.get(0)
# Out:
# 0    2023
# 1    2202
# 2    2014
# dtype: object

# %%
pd.to_datetime(s)
# Out:
# 0   2023-01-01
# 1   2202-05-02
# 2   2014-08-25
# dtype: datetime64[ns]

# %%
pd.to_datetime(s).dt.month
# Out:
# 0    1
# 1    5
# 2    8
# dtype: int32

# %%
s=pd.Series(['2023/1/1','2202/115/2','2014/8/25'])
s
# Out:
# 0      2023/1/1
# 1    2202/115/2
# 2     2014/8/25
# dtype: object

# %%
pd.to_datetime(s,errors='coerce')
# Out:
# 0   2023-01-01
# 1          NaT
# 2   2014-08-25
# dtype: datetime64[ns]

# %%
df=pd.read_csv('/content/expense_data.csv')
df.head()
# Out:
#              Date               Account        Category  Subcategory  \
# 0  3/2/2022 10:11  CUB - online payment            Food          NaN
# 1  3/2/2022 10:11  CUB - online payment           Other          NaN
# 2  3/1/2022 19:50  CUB - online payment            Food          NaN
# 3  3/1/2022 18:56  CUB - online payment  Transportation          NaN
# 4  3/1/2022 18:22  CUB - online payment            Food          NaN
#
#                Note    INR Income/Expense  Note.1  Amount Currency  Account.1
# 0           Brownie   50.0        Expense     NaN    50.0      INR       50.0
# 1  To lended people  300.0        Expense     NaN   300.0      INR      300.0
# 2            Dinner   78.0        Expense     NaN    78.0      INR       78.0
# 3             Metro   30.0        Expense     NaN    30.0      INR       30.0
# 4            Snacks   67.0        Expense     NaN    67.0      INR       67.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 277 entries, 0 to 276
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            277 non-null    object
#  1   Account         277 non-null    object
#  2   Category        277 non-null    object
#  3   Subcategory     0 non-null      float64
#  4   Note            273 non-null    object
#  5   INR             277 non-null    float64
#  6   Income/Expense  277 non-null    object
#  7   Note.1          0 non-null      float64
#  8   Amount          277 non-null    float64
#  9   Currency        277 non-null    object
#  10  Account.1       277 non-null    float64
# dtypes: float64(5), object(6)
# memory usage: 23.9+ KB

# %%
df['Date']=pd.to_datetime(df['Date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 277 entries, 0 to 276
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            277 non-null    datetime64[ns]
#  1   Account         277 non-null    object
#  2   Category        277 non-null    object
#  3   Subcategory     0 non-null      float64
#  4   Note            273 non-null    object
#  5   INR             277 non-null    float64
#  6   Income/Expense  277 non-null    object
#  7   Note.1          0 non-null      float64
#  8   Amount          277 non-null    float64
#  9   Currency        277 non-null    object
#  10  Account.1       277 non-null    float64
# dtypes: datetime64[ns](1), float64(5), object(5)
# memory usage: 23.9+ KB

# %%
df['Date'].dt.day_name()
# Out:
# 0      Wednesday
# 1      Wednesday
# 2        Tuesday
# 3        Tuesday
# 4        Tuesday
#          ...
# 272       Monday
# 273       Monday
# 274       Sunday
# 275       Sunday
# 276       Sunday
# Name: Date, Length: 277, dtype: object

# %%
import matplotlib.pyplot as plt
plt.plot(df['Date'],df['INR'])

# %%
import matplotlib.pyplot as plt
plt.plot(df['INR'],df['Date'])

# %%
df['day_name']=df['Date'].dt.day_name()

# %%
df.head()
# Out:
#                  Date               Account        Category  Subcategory  \
# 0 2022-03-02 10:11:00  CUB - online payment            Food          NaN
# 1 2022-03-02 10:11:00  CUB - online payment           Other          NaN
# 2 2022-03-01 19:50:00  CUB - online payment            Food          NaN
# 3 2022-03-01 18:56:00  CUB - online payment  Transportation          NaN
# 4 2022-03-01 18:22:00  CUB - online payment            Food          NaN
#
#                Note    INR Income/Expense  Note.1  Amount Currency  Account.1  \
# 0           Brownie   50.0        Expense     NaN    50.0      INR       50.0
# 1  To lended people  300.0        Expense     NaN   300.0      INR      300.0
# 2            Dinner   78.0        Expense     NaN    78.0      INR       78.0
# 3             Metro   30.0        Expense     NaN    30.0      INR       30.0
# 4            Snacks   67.0        Expense     NaN    67.0      INR       67.0
#
#     day_name
# 0  Wednesday
# 1  Wednesday
# 2    Tuesday
# ...

# %%
df.groupby('day_name')['INR'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='day_name'>

# %%
df['month_name']=df['Date'].dt.month_name()
df
# Out:
#                    Date               Account        Category  Subcategory  \
# 0   2022-03-02 10:11:00  CUB - online payment            Food          NaN
# 1   2022-03-02 10:11:00  CUB - online payment           Other          NaN
# 2   2022-03-01 19:50:00  CUB - online payment            Food          NaN
# 3   2022-03-01 18:56:00  CUB - online payment  Transportation          NaN
# 4   2022-03-01 18:22:00  CUB - online payment            Food          NaN
# ..                  ...                   ...             ...          ...
# 272 2021-11-22 14:16:00  CUB - online payment            Food          NaN
# 273 2021-11-22 14:16:00  CUB - online payment            Food          NaN
# 274 2021-11-21 17:07:00  CUB - online payment  Transportation          NaN
# 275 2021-11-21 15:50:00  CUB - online payment            Food          NaN
# 276 2021-11-21 13:30:00  CUB - online payment           Other          NaN
#
# ...

# %%
df.groupby('month_name')['INR'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='month_name'>
